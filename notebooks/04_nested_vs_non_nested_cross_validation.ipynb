# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, PredefinedSplit
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # 1. Prepare Dataset

# %% [markdown]
# ## 1.1. Make Random, Uncorrelated Dataset

# %%
N = 1_000

# %%
train_size = 0.65

# %%
np.random.seed(12345)

# %%
X_numeric = pd.DataFrame(
    data=np.random.randn(5*N).reshape(-1, 5),
    columns=[f"X{k}" for k in range(1, 6, 1)]
)

# %%
X_categ = pd.DataFrame(
    data={
        "X_binary": np.random.binomial(n=1, p=0.5, size=N),
        "X_ternary": np.random.binomial(n=3, p=0.5, size=N)
    }
)

# %%
X = pd.concat([X_numeric, X_categ], axis=1)

# %%
y = pd.DataFrame(data={"y": np.random.binomial(n=1, p=0.5, size=N)})

# %%
X.head()
# Out:
#          X1        X2        X3        X4        X5  X_binary  X_ternary
# 0 -0.204708  0.478943 -0.519439 -0.555730  1.965781         1          1
# 1  1.393406  0.092908  0.281746  0.769023  1.246435         1          1
# 2  1.007189 -1.296221  0.274992  0.228913  1.352917         1          2
# 3  0.886429 -2.001637 -0.371843  1.669025 -0.438570         1          2
# 4 -0.539741  0.476985  3.248944 -1.021228 -0.577087         1          1

# %% [markdown]
# ## 2.1. Split Data into Train, Validation and Test

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, train_size=train_size)

# %%
X_train_val = X_train_val.reset_index(drop=True)
y_train_val = y_train_val.reset_index(drop=True)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, train_size=0.8)

# %% [markdown]
# # 2. Define Grid of Hyperparameters

# %%
hyperparams = {
    "criterion": ["gini", "entropy"],
    "max_depth": [1, 3, 5, 10, 20, None],
    "max_features": [5, 10, "sqrt", "log2", None]
}

# %% [markdown]
# # 3. Define the Single Split to be Used in Cross Validation - Enforce Using Incorrect Approach

# %%
ps_vec = np.zeros(X_train_val.shape[0])
ps_vec[X_train.index] = -1
ps_vec[X_val.index] = 1

# %%
cv_predef_split = PredefinedSplit(ps_vec)

# %% [markdown]
# # 4. Run the Grid Search Cross-Validation

# %%
gs_cv = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=hyperparams,
    scoring="roc_auc",
    cv=cv_predef_split
)

# %%
gs_cv.fit(X_train_val, y_train_val)
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ..., -1,  1], shape=(650,))),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 3, 5, 10, 20, None],
#                          'max_features': [5, 10, 'sqrt', 'log2', None]},
#              scoring='roc_auc')

# %%
gs_cv.best_score_
# Out:
# np.float64(0.6058925049309664)

# %%
cv_results = pd.DataFrame(gs_cv.cv_results_)

# %%
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005579           0.0         0.004164             0.0
# 1        0.001964           0.0         0.002080             0.0
# 2        0.001466           0.0         0.002557             0.0
# 3        0.001258           0.0         0.001652             0.0
# 4        0.001417           0.0         0.001625             0.0
# 5        0.001754           0.0         0.002099             0.0
# 6        0.002209           0.0         0.001641             0.0
# 7        0.001296           0.0         0.001587             0.0
# 8        0.001216           0.0         0.001958             0.0
# 9        0.001941           0.0         0.001511             0.0
# 10       0.001844           0.0         0.001466             0.0
# 11       0.002119           0.0         0.001451             0.0
# 12       0.001196           0.0         0.001294             0.0
# 13       0.001172           0.0         0.001550             0.0
# 14       0.002005           0.0         0.001352             0.0
# 15       0.002135           0.0         0.001333             0.0
# 16       0.002589           0.0         0.001361             0.0
# 17       0.001355           0.0         0.001328             0.0
# 18       0.001613           0.0         0.001487             0.0
# 19       0.002610           0.0         0.001361             0.0
# 20       0.002169           0.0         0.001298             0.0
# 21       0.002940           0.0         0.001472             0.0
# 22       0.001543           0.0         0.001393             0.0
# 23       0.001608           0.0         0.001319             0.0
# 24       0.002695           0.0         0.001465             0.0
# 25       0.002113           0.0         0.001303             0.0
# 26       0.002715           0.0         0.001341             0.0
# 27       0.001649           0.0         0.001383             0.0
# 28       0.001682           0.0         0.001340             0.0
# 29       0.002709           0.0         0.001335             0.0
# 30       0.001028           0.0         0.001280             0.0
# 31       0.001132           0.0         0.001266             0.0
# 32       0.000875           0.0         0.001302             0.0
# 33       0.000995           0.0         0.001285             0.0
# 34       0.001132           0.0         0.001275             0.0
# 35       0.001434           0.0         0.001294             0.0
# 36       0.001724           0.0         0.001280             0.0
# 37       0.001074           0.0         0.001285             0.0
# 38       0.001068           0.0         0.001268             0.0
# 39       0.001793           0.0         0.001321             0.0
# 40       0.001869           0.0         0.001301             0.0
# 41       0.002256           0.0         0.001302             0.0
# 42       0.001283           0.0         0.001280             0.0
# 43       0.001150           0.0         0.001280             0.0
# 44       0.002281           0.0         0.001286             0.0
# 45       0.002843           0.0         0.001298             0.0
# 46       0.003259           0.0         0.001331             0.0
# 47       0.001757           0.0         0.001296             0.0
# 48       0.001579           0.0         0.001298             0.0
# 49       0.003244           0.0         0.001333             0.0
# 50       0.002791           0.0         0.001303             0.0
# 51       0.003631           0.0         0.001324             0.0
# 52       0.001955           0.0         0.001301             0.0
# 53       0.001721           0.0         0.001315             0.0
# 54       0.003605           0.0         0.001288             0.0
# 55       0.002560           0.0         0.001311             0.0
# 56       0.003629           0.0         0.001306             0.0
# 57       0.001698           0.0         0.001296             0.0
# 58       0.001794           0.0         0.001274             0.0
# 59       0.003606           0.0         0.001336             0.0
#
#    param_criterion param_max_depth param_max_features  \
# 0             gini               1                  5
# 1             gini               1                 10
# 2             gini               1               sqrt
# 3             gini               1               log2
# 4             gini               1               None
# 5             gini               3                  5
# 6             gini               3                 10
# 7             gini               3               sqrt
# 8             gini               3               log2
# 9             gini               3               None
# 10            gini               5                  5
# 11            gini               5                 10
# 12            gini               5               sqrt
# 13            gini               5               log2
# 14            gini               5               None
# 15            gini              10                  5
# 16            gini              10                 10
# 17            gini              10               sqrt
# 18            gini              10               log2
# 19            gini              10               None
# 20            gini              20                  5
# 21            gini              20                 10
# 22            gini              20               sqrt
# 23            gini              20               log2
# 24            gini              20               None
# 25            gini            None                  5
# 26            gini            None                 10
# 27            gini            None               sqrt
# 28            gini            None               log2
# 29            gini            None               None
# 30         entropy               1                  5
# 31         entropy               1                 10
# 32         entropy               1               sqrt
# 33         entropy               1               log2
# 34         entropy               1               None
# 35         entropy               3                  5
# 36         entropy               3                 10
# 37         entropy               3               sqrt
# 38         entropy               3               log2
# 39         entropy               3               None
# 40         entropy               5                  5
# 41         entropy               5                 10
# 42         entropy               5               sqrt
# 43         entropy               5               log2
# 44         entropy               5               None
# 45         entropy              10                  5
# 46         entropy              10                 10
# 47         entropy              10               sqrt
# 48         entropy              10               log2
# 49         entropy              10               None
# 50         entropy              20                  5
# 51         entropy              20                 10
# 52         entropy              20               sqrt
# 53         entropy              20               log2
# 54         entropy              20               None
# 55         entropy            None                  5
# 56         entropy            None                 10
# 57         entropy            None               sqrt
# 58         entropy            None               log2
# 59         entropy            None               None
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 1, 'max_fea...           0.538462
# 1   {'criterion': 'gini', 'max_depth': 1, 'max_fea...           0.538462
# 2   {'criterion': 'gini', 'max_depth': 1, 'max_fea...           0.509615
# 3   {'criterion': 'gini', 'max_depth': 1, 'max_fea...           0.538462
# 4   {'criterion': 'gini', 'max_depth': 1, 'max_fea...           0.538462
# 5   {'criterion': 'gini', 'max_depth': 3, 'max_fea...           0.428254
# 6   {'criterion': 'gini', 'max_depth': 3, 'max_fea...           0.520710
# 7   {'criterion': 'gini', 'max_depth': 3, 'max_fea...           0.577046
# 8   {'criterion': 'gini', 'max_depth': 3, 'max_fea...           0.449088
# 9   {'criterion': 'gini', 'max_depth': 3, 'max_fea...           0.520710
# 10  {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.519354
# 11  {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.500863
# 12  {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.572485
# 13  {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.552268
# 14  {'criterion': 'gini', 'max_depth': 5, 'max_fea...           0.500863
# 15  {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.545735
# 16  {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.446376
# 17  {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.572115
# 18  {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.555350
# 19  {'criterion': 'gini', 'max_depth': 10, 'max_fe...           0.445020
# 20  {'criterion': 'gini', 'max_depth': 20, 'max_fe...           0.493590
# 21  {'criterion': 'gini', 'max_depth': 20, 'max_fe...           0.464744
# 22  {'criterion': 'gini', 'max_depth': 20, 'max_fe...           0.445513
# 23  {'criterion': 'gini', 'max_depth': 20, 'max_fe...           0.535256
# 24  {'criterion': 'gini', 'max_depth': 20, 'max_fe...           0.471154
# 25  {'criterion': 'gini', 'max_depth': None, 'max_...           0.483974
# 26  {'criterion': 'gini', 'max_depth': None, 'max_...           0.464744
# 27  {'criterion': 'gini', 'max_depth': None, 'max_...           0.480769
# 28  {'criterion': 'gini', 'max_depth': None, 'max_...           0.493590
# 29  {'criterion': 'gini', 'max_depth': None, 'max_...           0.464744
# 30  {'criterion': 'entropy', 'max_depth': 1, 'max_...           0.538462
# 31  {'criterion': 'entropy', 'max_depth': 1, 'max_...           0.538462
# 32  {'criterion': 'entropy', 'max_depth': 1, 'max_...           0.538462
# 33  {'criterion': 'entropy', 'max_depth': 1, 'max_...           0.503205
# 34  {'criterion': 'entropy', 'max_depth': 1, 'max_...           0.538462
# 35  {'criterion': 'entropy', 'max_depth': 3, 'max_...           0.581731
# 36  {'criterion': 'entropy', 'max_depth': 3, 'max_...           0.545981
# 37  {'criterion': 'entropy', 'max_depth': 3, 'max_...           0.512081
# 38  {'criterion': 'entropy', 'max_depth': 3, 'max_...           0.560651
# 39  {'criterion': 'entropy', 'max_depth': 3, 'max_...           0.545981
# 40  {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.511464
# 41  {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.482125
# 42  {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.548200
# 43  {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.605893
# 44  {'criterion': 'entropy', 'max_depth': 5, 'max_...           0.482372
# 45  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.535503
# 46  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.491371
# 47  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.540557
# 48  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.537229
# 49  {'criterion': 'entropy', 'max_depth': 10, 'max...           0.472387
# 50  {'criterion': 'entropy', 'max_depth': 20, 'max...           0.478304
# 51  {'criterion': 'entropy', 'max_depth': 20, 'max...           0.500000
# 52  {'criterion': 'entropy', 'max_depth': 20, 'max...           0.543886
# 53  {'criterion': 'entropy', 'max_depth': 20, 'max...           0.496795
# 54  {'criterion': 'entropy', 'max_depth': 20, 'max...           0.490385
# 55  {'criterion': 'entropy', 'max_depth': None, 'm...           0.560897
# 56  {'criterion': 'entropy', 'max_depth': None, 'm...           0.474359
# 57  {'criterion': 'entropy', 'max_depth': None, 'm...           0.480769
# 58  {'criterion': 'entropy', 'max_depth': None, 'm...           0.509615
# 59  {'criterion': 'entropy', 'max_depth': None, 'm...           0.480769
#
#     mean_test_score  std_test_score  rank_test_score
# 0          0.538462             0.0               16
# 1          0.538462             0.0               16
# 2          0.509615             0.0               32
# 3          0.538462             0.0               16
# 4          0.538462             0.0               16
# 5          0.428254             0.0               60
# 6          0.520710             0.0               27
# 7          0.577046             0.0                3
# 8          0.449088             0.0               56
# 9          0.520710             0.0               27
# 10         0.519354             0.0               29
# 11         0.500863             0.0               35
# 12         0.572485             0.0                4
# 13         0.552268             0.0                9
# 14         0.500863             0.0               35
# 15         0.545735             0.0               13
# 16         0.446376             0.0               57
# 17         0.572115             0.0                5
# 18         0.555350             0.0                8
# 19         0.445020             0.0               59
# 20         0.493590             0.0               39
# 21         0.464744             0.0               53
# 22         0.445513             0.0               58
# 23         0.535256             0.0               26
# 24         0.471154             0.0               52
# 25         0.483974             0.0               43
# 26         0.464744             0.0               53
# 27         0.480769             0.0               46
# 28         0.493590             0.0               40
# 29         0.464744             0.0               53
# 30         0.538462             0.0               16
# 31         0.538462             0.0               16
# 32         0.538462             0.0               16
# 33         0.503205             0.0               34
# 34         0.538462             0.0               16
# 35         0.581731             0.0                2
# 36         0.545981             0.0               11
# 37         0.512081             0.0               30
# 38         0.560651             0.0                7
# 39         0.545981             0.0               11
# 40         0.511464             0.0               31
# 41         0.482125             0.0               45
# 42         0.548200             0.0               10
# 43         0.605893             0.0                1
# 44         0.482372             0.0               44
# 45         0.535503             0.0               25
# 46         0.491371             0.0               41
# 47         0.540557             0.0               15
# 48         0.537229             0.0               24
# 49         0.472387             0.0               51
# 50         0.478304             0.0               49
# 51         0.500000             0.0               37
# 52         0.543886             0.0               14
# 53         0.496795             0.0               38
# 54         0.490385             0.0               42
# 55         0.560897             0.0                6
# 56         0.474359             0.0               50
# 57         0.480769             0.0               46
# 58         0.509615             0.0               33
# 59         0.480769             0.0               46
